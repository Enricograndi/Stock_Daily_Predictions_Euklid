# %%
# General libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
# Machine Learning Libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Models libraries
from sklearn import svm
# Models tuning libraries
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Preliminary work on the dataset

# %%
yahoo_df = pd.read_csv("../data/IBM.csv")
yahoo_df = yahoo_df.set_index("Date")

X = yahoo_df[['ROC_4', 'ROC_5', 'ROC_6', '4 Day ROI', '6 Day ROI', '30 Day ROI',
       'RSI_3', 'RSI_4', 'CCI']]

y = yahoo_df["Up down"]

# Split in 80/20 the dataframeX
X_train_80, X_test, y_train_80, y_test = train_test_split(X, y, test_size = 0.20,
                                                          shuffle=False)

# Split in 75/25 the remaining 80 %
X_train, X_valid, y_train, y_valid = train_test_split(X_train_80, y_train_80,
                                                      test_size = 0.25, shuffle=False)

# %% [markdown]
# # Normalize

# %%
def shift_norm(df):
    #df = data
    for column in df:
        df[column]=((df[column]-df[column].mean())/df[column].std())
    return df

# %%
X_train_80 = shift_norm(X_train_80)
X_test = shift_norm(X_test)

# %%
X_train = shift_norm(X_train)
X_valid = shift_norm(X_valid)

# %% [markdown]
# # Support Vector Machine (SVC)

# %%
SVC = svm.SVC(random_state = 42, kernel='linear')

# Fit the model
SVC.fit(X_train, y_train)

# Predict
y_pred_train = SVC.predict(X_train)
y_pred_valid = SVC.predict(X_valid)

# Compute accuracy
train_acc = accuracy_score(y_train, y_pred_train)
valid_acc = accuracy_score(y_valid, y_pred_valid)
print("Train Accuracy: {:.5f} - Validation Accuracy: {:.5f}".format(train_acc, valid_acc))
# Out:
# Train Accuracy: 0.55815 - Validation Accuracy: 0.48644

# %%
y_pred_test = SVC.predict(X_test)
# Finally evaluate on test
test_acc = accuracy_score(y_test, y_pred_test)
print ("Test Accuracy: {:.5f}".format(test_acc) )

# Store the Test Accuracy 
SVC_accuracy_test = test_acc
# Out:
# Test Accuracy: 0.47664

# %% [markdown]
# ### Tuning parametres with GridSearchCV(VERY SLOW!!)
#
# We make parameters tuning using the GridSearchCV instance. This one allows us to fit on a dataset all the possible combinations of parameter values. Moreover it evaluates and retaines the best combination of parameters.

# %% [markdown]
# # Applying Gridsearchcv for parameters tuning
# # 'poly' --> molto lento
# # Setting C parameters
# parameters = [{'C': [0.1, 1.0, 10, 50, 100 ],
#               'gamma': [1,0.1,0.001],
#                 'kernel': ['linear','rbf', 'sigmoid',"poly"]
#               }]
# best_SVC = GridSearchCV(estimator = svm.SVC(),refit=True,verbose=2,
#                              param_grid = parameters, scoring = 'accuracy')
#
# # Fit the model
# best_SVC.fit(X_train, y_train)
#
# print(best_SVC.best_estimator_)

# %%
SVC = svm.SVC(C=10, gamma=1, kernel='linear',probability=True)

# Fit the model
SVC.fit(X_train_80, y_train_80)

# Predict
y_pred_train = SVC.predict(X_train)
y_pred_valid = SVC.predict(X_valid)

# Compute accuracy
train_acc = accuracy_score(y_train, y_pred_train)
valid_acc = accuracy_score(y_valid, y_pred_valid)
print("Train Accuracy: {:.5f} - Validation Accuracy: {:.5f}".format(train_acc, valid_acc))
# Out:
# Train Accuracy: 0.55535 - Validation Accuracy: 0.49579

# %%
y_pred_test = SVC.predict(X_test)
y_prob = SVC.predict_proba(X_test)[:,1]

# Finally evaluate on test
test_acc = accuracy_score(y_test, y_pred_test)
print ("Test Accuracy: {:.5f}".format(test_acc) )

# Store the Test Accuracy 
SVC_accuracy_test = test_acc
# Out:
# Test Accuracy: 0.49252

# %% [markdown]
# # Predict on all data

# %%
df_prediction = pd.read_csv("../data/model_accuracy_IBM.csv", index_col = False)
df_prediction =  df_prediction.drop(columns=["Unnamed: 0"])

df_prediction
# Out:
#       LogReg_pred  LogReg_accuracy  LogReg_prob  LGBM_pred  LGBM_accuracy  \
# 0               0          0.48785     0.499232          0        0.48972
# 1               1          0.48785     0.504807          1        0.48972
# 2               1          0.48785     0.591117          1        0.48972
# 3               1          0.48785     0.595272          1        0.48972
# 4               1          0.48785     0.590655          1        0.48972
# ...           ...              ...          ...        ...            ...
# 1065            1          0.48785     0.543262          1        0.48972
# 1066            1          0.48785     0.570132          1        0.48972
# 1067            1          0.48785     0.542180          1        0.48972
# 1068            1          0.48785     0.569741          1        0.48972
# 1069            1          0.48785     0.543188          1        0.48972
#
#       LGBM_prob  y  kNN_pred  kNN_accuracy  kNN_prob  ANN_pred  ANN_accuracy  \
# 0      0.482038  0         0      0.508411       0.5         0      0.483178
# 1      0.516175  1         0      0.508411       0.5         1      0.483178
# 2      0.526401  1         0      0.508411       0.5         1      0.483178
# 3      0.515859  1         1      0.508411       1.0         1      0.483178
# 4      0.515859  1         1      0.508411       1.0         1      0.483178
# ...         ... ..       ...           ...       ...       ...           ...
# 1065   0.536454  1         0      0.508411       0.5         1      0.483178
# 1066   0.521491  1         1      0.508411       1.0         1      0.483178
# 1067   0.537546  0         1      0.508411       1.0         1      0.483178
# 1068   0.521313  1         0      0.508411       0.5         1      0.483178
# 1069   0.521491  0         1      0.508411       1.0         1      0.483178
#
#       ANN_prob  RF_pred  RF_accuracy   RF_prob
# 0     0.490417        0     0.525234  0.422360
# 1     0.506478        1     0.525234  0.504748
# 2     0.594908        1     0.525234  0.635901
# 3     0.625306        1     0.525234  0.800362
# 4     0.620808        1     0.525234  0.617615
# ...        ...      ...          ...       ...
# 1065  0.507600        1     0.525234  0.669753
# 1066  0.546710        1     0.525234  0.765041
# 1067  0.533604        1     0.525234  0.747523
# 1068  0.560094        1     0.525234  0.580589
# 1069  0.541299        1     0.525234  0.715220
#
# [1070 rows x 16 columns]

# %%
df_prediction["SVC_pred"] = y_pred_test
df_prediction["SVC_accuracy"] = [SVC_accuracy_test for x in range(len(y_pred_test))]
df_prediction["SVC_prob"] = y_prob

# %%
df_prediction
# Out:
#       LogReg_pred  LogReg_accuracy  LogReg_prob  LGBM_pred  LGBM_accuracy  \
# 0               0          0.48785     0.499232          0        0.48972
# 1               1          0.48785     0.504807          1        0.48972
# 2               1          0.48785     0.591117          1        0.48972
# 3               1          0.48785     0.595272          1        0.48972
# 4               1          0.48785     0.590655          1        0.48972
# ...           ...              ...          ...        ...            ...
# 1065            1          0.48785     0.543262          1        0.48972
# 1066            1          0.48785     0.570132          1        0.48972
# 1067            1          0.48785     0.542180          1        0.48972
# 1068            1          0.48785     0.569741          1        0.48972
# 1069            1          0.48785     0.543188          1        0.48972
#
#       LGBM_prob  y  kNN_pred  kNN_accuracy  kNN_prob  ANN_pred  ANN_accuracy  \
# 0      0.482038  0         0      0.508411       0.5         0      0.483178
# 1      0.516175  1         0      0.508411       0.5         1      0.483178
# 2      0.526401  1         0      0.508411       0.5         1      0.483178
# 3      0.515859  1         1      0.508411       1.0         1      0.483178
# 4      0.515859  1         1      0.508411       1.0         1      0.483178
# ...         ... ..       ...           ...       ...       ...           ...
# 1065   0.536454  1         0      0.508411       0.5         1      0.483178
# 1066   0.521491  1         1      0.508411       1.0         1      0.483178
# 1067   0.537546  0         1      0.508411       1.0         1      0.483178
# 1068   0.521313  1         0      0.508411       0.5         1      0.483178
# 1069   0.521491  0         1      0.508411       1.0         1      0.483178
#
#       ANN_prob  RF_pred  RF_accuracy   RF_prob  SVC_pred  SVC_accuracy  \
# 0     0.490417        0     0.525234  0.422360         1      0.492523
# 1     0.506478        1     0.525234  0.504748         1      0.492523
# 2     0.594908        1     0.525234  0.635901         1      0.492523
# 3     0.625306        1     0.525234  0.800362         1      0.492523
# 4     0.620808        1     0.525234  0.617615         1      0.492523
# ...        ...      ...          ...       ...       ...           ...
# 1065  0.507600        1     0.525234  0.669753         1      0.492523
# 1066  0.546710        1     0.525234  0.765041         1      0.492523
# 1067  0.533604        1     0.525234  0.747523         1      0.492523
# 1068  0.560094        1     0.525234  0.580589         1      0.492523
# 1069  0.541299        1     0.525234  0.715220         1      0.492523
#
#       SVC_prob
# 0     0.517458
# 1     0.517960
# 2     0.526435
# 3     0.527133
# 4     0.526471
# ...        ...
# 1065  0.522732
# 1066  0.524813
# 1067  0.522923
# 1068  0.524824
# 1069  0.523085
#
# [1070 rows x 19 columns]

# %%
df_prediction.to_csv("../data/model_accuracy_IBM.csv")

# %%
# Plot the confusion matrix
#conf_stat = confusion_matrix(y_test, y_pred_test)
#ut.plot_confusion_matrix(conf_stat, Linearmodel_nt.classes_)
